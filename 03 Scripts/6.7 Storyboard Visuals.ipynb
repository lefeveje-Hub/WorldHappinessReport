# %% [markdown]
# # 6.7 Storyboard Visuals

# %% [markdown]
# ## Import

# %%
# Import libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
import sklearn
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Import happiness dataframe

path = r'C:\Users\lefev\Documents\Data Analytics Course\Achievement 6'

# %%
df = pd.read_csv(os.path.join(path, 'Data', 'combined_happiness_data.csv'), index_col=False)

# %% [markdown]
# ## Create Visual for Exploratory Slide

# %%
# Create a scatterplot for the "Freedom to make life choices" and "score" columns in seaborn

sns.scatterplot(x = 'Freedom to make life choices', y = 'Score', data = df)
# Out:
# <Axes: xlabel='Freedom to make life choices', ylabel='Score'>

# %% [markdown]
# ## Now run a linear regression with a linear line

# %%
sns.regplot(x='Freedom to make life choices', y='Score', data=df,
            scatter_kws={'color': '#3498db', 'alpha': 0.5},
            line_kws={'color': '#e74c3c', 'linewidth': 2})
# Out:
# <Axes: xlabel='Freedom to make life choices', ylabel='Score'>
